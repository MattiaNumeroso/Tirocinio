# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore", message="n_jobs value 1 overridden to 1 by setting random_state.")
warnings.filterwarnings("ignore", message="MiniBatchKMeans is known to have a memory leak on Windows with MKL")

import time
import os
os.environ["OMP_NUM_THREADS"] = "2"

from scipy import stats
from scipy.stats import *
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster

from sklearn import datasets
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.metrics.pairwise import euclidean_distances, cosine_distances
from sklearn.metrics.cluster import adjusted_rand_score
from sklearn.cluster import KMeans, MiniBatchKMeans
from sklearn.metrics import silhouette_score

import umap

# %%
combined_dataset_r = pd.read_csv(r"C:\Users\matti\OneDrive\Desktop\Tirocinio\Genomica\Vivi con ricorrenza\Dataset_407_pazienti_recidiv.csv", index_col=0)

# %%
ciao = ['Type', 'Unnamed: 0', 'Patient_ID', 'Study_Name', 'Study_OID',
       'Study_Start_Date', 'clinical_Age_at_Diagnosis',
       'clinical_Date_of_first_Diagnosis', 'clinical_Hospital', 'clinical_Sex',
       'ctn_Anatomical_Tumor_Location', 'ctn_Laterality_of_T',
       'ctn_Stage_at_Diagnosis_7Edition', 'ctn_TNM_cN_7Edition',
       'ctn_TNM_cT_7Edition', 'ctn_Tumor_Region',
       'follow_Date_of_Examination_or_Last_Contact',
       'follow_Date_of_Recurrence', 'follow_Follow_Up_Period',
       'follow_Recurrence', 'follow_Status_of_Patient',
       'follow_Treatment_of_Recurrence', 'follow_Type_of_Recurrence',
       'patho_HPV_Status_Evaluated', 'patient_Consent',
       'patient_Eligibility_Criteria', 'risk_Additional_precancerous_lesion_1',
       'risk_Alcohol_at_Time_of_Diagnosis',
       'risk_Family_History_of_Malignancies', 'risk_Oral_Hygiene',
       'risk_Smoker_at_Time_of_Diagnosis', 'Recurrence_Tumor',
       'Recurrence_Alive', 'Recurrence_Dead', 'Status_Alive', 'Status_Dead']

r = combined_dataset_r['Study_Start_Date']

# %%
# Crea la nuova colonna con i valori basati sulle condizioni
combined_dataset_r['follow_Follow_Up_Period_3'] = combined_dataset_r['follow_Follow_Up_Period'].apply(
    lambda x: 1 if x < 40 else (2 if 40 <= x <= 80 else 3)
)

# Visualizza le prime righe per verificare
print(combined_dataset_r[['follow_Follow_Up_Period', 'follow_Follow_Up_Period_3']].head())
# Out:
#                 follow_Follow_Up_Period  follow_Follow_Up_Period_3
# SS_UDUS148                           11                          1
# SS_INT_MI_0045                       11                          1
# SS_INT_MI_0103                        7                          1
# SS_INT_MI_0055                       23                          1
# SS_INT_0064                          22                          1

# %%
# Out:
#                          0         1         2         3         4         5  \
# SS_UDUS148        2.892422 -0.226992 -0.625910 -0.449340  0.243863 -0.305467
# SS_INT_MI_0045    1.181239 -0.407873 -0.937577 -0.645136 -0.280964 -0.198198
# SS_INT_MI_0103    0.965505 -0.586660 -0.771575 -0.793989 -0.211227 -0.659505
# SS_INT_MI_0055    1.134780 -0.486895 -0.678935 -0.662932  0.366618 -0.721611
# SS_INT_0064       0.771911  0.307021  0.029719 -0.557509  0.584324 -0.435170
# ...                    ...       ...       ...       ...       ...       ...
# SS_VUMC_HPL_7464  0.253040  0.395856 -0.603859 -0.889491  0.931418  0.717193
# SS_VUMC_HPL_3711  0.522150 -0.411490 -1.003724 -1.010691  0.250419  0.027460
# SS_VUMC_HPL_8612  0.575902 -0.827952 -0.930258 -0.856371  0.109845 -0.503986
# SS_VUMC_HPL_4174  0.116059 -0.461632 -0.766827 -0.968474 -0.031089 -0.461632
# SS_VUMC_HPL_5181  0.238956 -0.112573 -0.262160 -0.703441  0.223997 -0.292077
#
# ...

# %%
combined_dataset_r['follow_Type_of_Recurrence'].unique()
# Out:
# array(['Delayed lymp node metastasis', 'Locoregional', 'Local',
#        'Regional', 'Distant metastasis', 'Local,Distant metastasis',
#        'Locoregional,Distant metastasis',
#        'Local,Regional,Distant metastasis',
#        'Local,Regional,Locoregional,Delayed lymp node metastasis',
#        'Distant metastasis,Delayed lymp node metastasis',
#        'Local,Locoregional,Distant metastasis', 'Local,Locoregional',
#        'Local,Regional', 'Second primary tumor',
#        'Second primary tumor,Distant metastasis',
#        'Regional,Second primary tumor',
#        'Regional,Second primary tumor,Distant metastasis',
#        'Locoregional,Second primary tumor', 'Regional,Distant metastasis',
#        'Local,Regional,Second primary tumor'], dtype=object)

# %%
date_object = []
for date_string in r:
    # Converti la stringa in un oggetto datetime
    l = datetime.strptime(date_string, '%Y-%m-%d')
    # Ricava l'anno
    anno = l.year
    # Aggiungi l'anno alla lista
    date_object.append(anno)

# date_object.unique()
unique_years = list(set(date_object))
print(unique_years)  # Output: [2017, 2018, 2019]
# Out:
# [2016, 2017, 2018, 2019, 2015]

# %%
from datetime import datetime

# Stringa della data
date_string = '2017-06-08'

# Converti la stringa in un oggetto datetime
date_object = datetime.strptime(date_string, '%Y-%d-%m')


# Stampa i risultati
print(f"Anno: {anno}")
print(f"Mese: {mese}")
print(f"Giorno: {giorno}")
# Out:
# Anno: 2017
# Mese: 8
# Giorno: 6
